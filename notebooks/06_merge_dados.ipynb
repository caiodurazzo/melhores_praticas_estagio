# %% [markdown]
# ## Merge dos dados

# %% [markdown]
# Nesse notebook são mescladas as bases de dados do projeto

# %%
from utils.load_csv import load_csv
from utils.load_shp import load_shp
from utils.save_shp import save_shp
import pandas as pd

# %%
df_ppa_fonte = load_csv("ppa_fonte.csv")

df_ppa_reg = load_csv("ppa_reg.csv")

gdf_subprefs = load_shp("subprefs.shp")

# %% [markdown]
# #### Merge dos PPAs

# %% [markdown]
# Mescla as bases de dados do PPA

# %%
df_ppa_merged = df_ppa_fonte.merge(df_ppa_reg,
                                   left_on = "id",
                                   right_on = "id",
                                   how = "left")

# %% [markdown]
# #### Merge dos PPAs com as subprefeituras

# %% [markdown]
# Mescla a base dos PPAs com a base do GeoSampa

# %%
gdf_merged = gdf_subprefs.merge(df_ppa_merged,
                                left_on = "nm_subpref",
                                right_on = "descricao prefeitura regional",
                                how = "left")

# %% [markdown]
# #### Salvar

# %%
pd.set_option("display.max_columns", None)

gdf_merged.sample(10)
# Out:
#        cd_identif cd_subpref        nm_subpref tx_escala sg_fonte_o  \
# 5732         11.0         27          ITAQUERA    1:5000     GEOGSG
# 10859         1.0         02  PIRITUBA-JARAGUA    1:5000     GEOGSG
# 6519         31.0         01             PERUS    1:5000     GEOGSG
# 2066         12.0         28        GUAIANASES    1:5000     GEOGSG
# 2701         32.0         32         SAPOPEMBA    1:5000     GEOGSG
# 5882         11.0         27          ITAQUERA    1:5000     GEOGSG
# 7051         20.0         12      VILA MARIANA    1:5000     GEOGSG
# 15           26.0         16     CIDADE ADEMAR    1:5000     GEOGSG
# 2161         12.0         28        GUAIANASES    1:5000     GEOGSG
# 2257         29.0         14       SANTO AMARO    1:5000     GEOGSG
#
#       dt_criacao  cd_tipo_di dt_atualiz cd_usuario sg_subpref  qt_area_qu  \
# 5732  2023-11-30   100200300 2025-07-05       None         IQ        55.0
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

save_shp(gdf_merged, "gdf_merged.shp")
# Out:
# Shapefile salvo em data\gdf_merged.shp
